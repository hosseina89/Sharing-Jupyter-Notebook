# %%
import Pkg
Pkg.add("Plots")

# if you want the latest features:
Pkg.pkg"add Plots#master"
Pkg.add("GR")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 % Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
#   [91a5bcdd]   Plots v0.28.4
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#   [91a5bcdd]   Plots v0.28.4
#   Updating git-repo `https://github.com/JuliaPlots/Plots.jl.git`
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
#   [91a5bcdd]   Plots v0.28.4 #master (https://github.com/JuliaPlots/Plots.jl.git)
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#   [91a5bcdd]   Plots v0.28.4 #master (https://github.com/JuliaPlots/Plots.jl.git)
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#  [no changes]

# %%
Pkg.add("PyPlot")
Pkg.add("GR")
#Pkg.add("Plotly")
Pkg.add("UnicodePlots")
Pkg.add("PlotlyJS")
Pkg.add("StatsPlots")
Pkg.add("PlotRecipes")
# Out:
# UndefVarError: Pkg not defined
#
# Stacktrace:
#  [1] top-level scope at In[88]:1

# %%
using Plots
n= 200
th = Array(0:6*pi/100:12*pi) # theta from 0 to 2pi ( + a little extra)

anim = @animate for i in 1:n
plt=plot3d(10,xlim=(-1.5,1.5),ylim=(-1.5,1.5),zlim=(0, 25), c=:red, size=(700, 700, 700))
    

t = th[1:i]
    
x = cos.(t/3)
y = sin.(t/3)
z = t/3
    
plot3d!(plt, cos.(t/3),sin.(t/3),t/3, c=:blue, camera=(0, 90), legend=false)
    

scatter!([x[end]],[y[end]],[z[end]], c=:red, markerstrokecolor=:red)
    

end

gif(anim)
# Out:
# ┌ Info: Saved animation to
# │   fn = /Users/alirezahosseinkhan/tmp.gif
# └ @ Plots /Users/alirezahosseinkhan/.julia/packages/Plots/qZHsp/src/animation.jl:98
# Plots.AnimatedGif("/Users/alirezahosseinkhan/tmp.gif")

# %%
using Plots
n= 300
th = Array(0:pi/150:2*pi) # theta from 0 to 2pi 
xc = cos.(th)
yc = sin.(th)

plt=plot!(xc, yc, c=:blue)
    


anim = @animate for i in 1:n
plot(10,xlim=(-2,2),ylim=(-2,2), c=:red, size=(700, 900), legend=false)
    

t = th[1:i]
    
x = cos.(t)
y = sin.(t)
    
plot!(plt, x,y, c=:blue, legend=false)
    

    scatter!([x[end]],[y[end]], c=:black, markerstrokecolor=:red)
    

end

gif(anim)
# Out:
# ┌ Info: Saved animation to
# │   fn = /Users/alirezahosseinkhan/tmp.gif
# └ @ Plots /Users/alirezahosseinkhan/.julia/packages/Plots/qZHsp/src/animation.jl:98
# Plots.AnimatedGif("/Users/alirezahosseinkhan/tmp.gif")

# %%
using PyPlot;
x =  collect(Float16, range(-5, length = 100, stop=5));
y = collect(Float16, range(-5, length = 100, stop=5));
z = x.+y;

#f(x,y)=sqrt(25-x.^2-y.^2)

surf(x,y,z);
# Out:
# PyError ($(Expr(:escape, :(ccall(#= /Users/alirezahosseinkhan/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:44 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'RuntimeError'>
# RuntimeError('Error in qhull Delaunay triangulation calculation: singular input data (exitcode=2); use python verbose option (-v) to see original qhull error.')
#   File "/Users/alirezahosseinkhan/.julia/conda/3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py", line 1989, in plot_trisurf
#     Triangulation.get_from_args_and_kwargs(*args, **kwargs)
#   File "/Users/alirezahosseinkhan/.julia/conda/3/lib/python3.7/site-packages/matplotlib/tri/triangulation.py", line 167, in get_from_args_and_kwargs
#     triangulation = Triangulation(x, y, triangles, mask)
#   File "/Users/alirezahosseinkhan/.julia/conda/3/lib/python3.7/site-packages/matplotlib/tri/triangulation.py", line 54, in __init__
#     self.triangles, self._neighbors = _qhull.delaunay(x, y)
#
#
# ...

# %%
using PyPlot;
x = collect(Float16, range(-2,length=100,stop=2));
y = collect(Float16, range(sqrt(2),length=100, stop=2));
z = x.-y;
surf(x,y,z);
# Out:
# PyError ($(Expr(:escape, :(ccall(#= /Users/alirezahosseinkhan/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:44 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'AttributeError'>
# AttributeError("'Poly3DCollection' object has no property 'camera'")
#   File "/Users/alirezahosseinkhan/.julia/conda/3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py", line 2003, in plot_trisurf
#     polyc = art3d.Poly3DCollection(verts, *args, **kwargs)
#   File "/Users/alirezahosseinkhan/.julia/conda/3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/art3d.py", line 597, in __init__
#     super().__init__(verts, *args, **kwargs)
#   File "/Users/alirezahosseinkhan/.julia/conda/3/lib/python3.7/site-packages/matplotlib/collections.py", line 1044, in __init__
#     Collection.__init__(self, **kwargs)
#   File "/Users/alirezahosseinkhan/.julia/conda/3/lib/python3.7/site-packages/matplotlib/collections.py", line 162, in __init__
#     self.update(kwargs)
# ...

# %%
using Plots; pyplot()
x=range(-4,stop=4,length=100)
y=range(-3,stop=3,length=100)
f(x,y) = sqrt(25-x.^2-y.^2)
p1=plot(x,y,f,st=:surface)

# %%
using Plots; pyplot()
n = 100
u = range(0,stop=2*π,length=n);
v = range(0,stop=π,length=n);

x =5* cos.(u) * sin.(v)';
y =5* sin.(u) * sin.(v)';
z =5* ones(n) * cos.(v)';

# The rstride and cstride arguments default to 10
#surf(x,y,z, rstride=2, cstride=2)
p1=plot!(x,y,z,st=:surface, color=:blues, size=(1000, 1000))


x = u;
y = pi/6;
p2=plot!(t,r, st=:surface, proj=:polar, color=:algae, size=(1000, 1000))

#plot(p1, p2, size=(1000, 500))

# %%
using Plots
n= 200
th = Array(0:pi/100:2*pi) # theta from 0 to 2pi ( + a little extra)

anim = @animate for i in 1:n
plt=plot3d(10,xlim=(-1.5,1.5),ylim=(-1.5,1.5),zlim=(0, 20), c=:red, size=(700, 700, 700))
    

t = th[1:i]
    
x = cos.(t)
y = sin.(t)
z = 5*(x.+y).+5
    
plot3d!(plt, cos.(t),sin.(t),5*(cos.(t).+sin.(t)).+5, c=:blue, camera=(90, 15), legend=false)
    

scatter!([x[end]],[y[end]],[z[end]], c=:red, markerstrokecolor=:red)
    

end

gif(anim)

# %%
$ jupyter nbconvert parameterization.ipynb --to html --output output.html
# Out:
# syntax: extra token "nbconvert" after end of expression

# %% [raw]
# $ jupyter nbconvert parameterization.ipynb --to html --output output.html

# %% [raw]
# $ jupyter nbconvert parameterization.ipynb --to pdf --output output.pdf
